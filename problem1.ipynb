# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
new_df=pd.read_csv("Weather Dataset.csv")
new_df
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 3775  2006-08-11 02:00:00.000 +0200  Mostly Cloudy        rain
# 3776  2006-12-26 12:00:00.000 +0100  Partly Cloudy        rain
# 3777  2006-12-19 20:00:00.000 +0100       Overcast        rain
# 3778  2006-12-10 11:00:00.000 +0100  Partly Cloudy        rain
# 3779  2006-12-10 15:00:00.000 +0100  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
# # #procces the data
new_df=new_df.drop_duplicates()  #to remove the duplicates
new_df=new_df.fillna(0)  #to handle with missing data
new_df=new_df[new_df["Temperature (C)"]>-100] #to remove incorrect values
new_df=new_df[new_df["Humidity"]>=0]
new_df=new_df.sort_values("Formatted Date")

# %%
new_df
# Out:
#                      Formatted Date   Summary Precip Type  Temperature (C)  \
# 2208  2006-02-01 00:00:00.000 +0100  Overcast        snow        -2.144444
# 2209  2006-02-01 01:00:00.000 +0100  Overcast        snow        -2.466667
# 2210  2006-02-01 02:00:00.000 +0100  Overcast        snow        -2.744444
# 2211  2006-02-01 03:00:00.000 +0100  Overcast        snow        -2.188889
# 2212  2006-02-01 04:00:00.000 +0100  Overcast        snow        -2.038889
# ...                             ...       ...         ...              ...
# 2059  2006-12-31 19:00:00.000 +0100     Foggy        snow        -0.827778
# 2060  2006-12-31 20:00:00.000 +0100     Foggy        snow        -2.011111
# 2061  2006-12-31 21:00:00.000 +0100     Foggy        snow        -1.500000
# 2062  2006-12-31 22:00:00.000 +0100     Foggy        snow        -0.950000
# 2063  2006-12-31 23:00:00.000 +0100     Foggy        snow        -0.672222
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
Temperature=np.array(new_df["Temperature (C)"])
Temperature
# Out:
# array([-2.14444444, -2.46666667, -2.74444444, ..., -1.5       ,
#        -0.95      , -0.67222222])

# %%
Humidity=np.array(new_df["Humidity"])
Humidity
# Out:
# array([0.86, 0.89, 0.89, ..., 0.96, 0.96, 0.93])

# %%
Time=np.array(new_df["Formatted Date"])

# %%
plt.plot(Time,Temperature,color='blue',label='blue line')
plt.title('Plot temperature over time.')
plt.ylabel('Temperature')
plt.xlabel('Time')


plt.show()

# %%
plt.scatter(Temperature,Humidity)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(Temperature)
plt.show()

# %%
numeric_df = new_df.applymap(lambda x: pd.to_numeric(x, errors='coerce'))
numeric_df = numeric_df.dropna(axis=1, how='any')
corr=numeric_df.corr()
# Out:
# C:\Users\Omar\AppData\Local\Temp\ipykernel_13140\186609527.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   numeric_df = new_df.applymap(lambda x: pd.to_numeric(x, errors='coerce'))

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()
